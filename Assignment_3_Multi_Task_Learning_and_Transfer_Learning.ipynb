# %% [markdown]
# <a href="https://colab.research.google.com/github/AbrahamKong/CMPE297-Multi_Task_Learning_and_Transfer_Learning/blob/main/Assignment_3_Multi_Task_Learning_and_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MMoE Multi Task Learning Model

# %%
import random

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import activations, initializers, regularizers, constraints
from tensorflow.keras.layers import Layer, InputSpec

from sklearn.metrics import roc_auc_score

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
FILE_PATH = "/content/drive/MyDrive/SJSU/CMPE 297: Advanced Deep Learning/Assignment #3: Multi Task Learning and Transfer Learning/"

# %%
class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.
        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.
        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.
        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.
        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.
        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %%
SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

# %%
# Simple callback to print out ROC-AUC
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        FILE_PATH + 'census-income.data.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        FILE_PATH + 'census-income.test.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info

# %%
# Load the data
train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
num_features = train_data.shape[1]

# %%
print('Training data shape = {}'.format(train_data.shape))
print('Validation data shape = {}'.format(validation_data.shape))
print('Test data shape = {}'.format(test_data.shape))
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)

# %%
# Set up the input layer
input_layer = Input(shape=(num_features,))

# %%
# Set up MMoE layer
mmoe_layers = MMoE(
  units=4,
  num_experts=8,
  num_tasks=2
)(input_layer)

output_layers = []

# %%
# Build tower layer from MMoE layer
for index, task_layer in enumerate(mmoe_layers):
  tower_layer = Dense(
    units=8,
    activation='relu',
    kernel_initializer=VarianceScaling())(task_layer)
  output_layer = Dense(
    units=output_info[index][0],
    name=output_info[index][1],
    activation='softmax',
    kernel_initializer=VarianceScaling())(tower_layer)
  output_layers.append(output_layer)

# %%
# Compile model
model = Model(inputs=[input_layer], outputs=output_layers)
adam_optimizer = Adam()
model.compile(
  loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
  optimizer=adam_optimizer,
  metrics=['accuracy']
)

# %%
# Print out model architecture summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 499)]        0           []
#
#  m_mo_e (MMoE)                  [(None, 4),          24000       ['input_1[0][0]']
#                                  (None, 4)]
#
#  dense (Dense)                  (None, 8)            40          ['m_mo_e[0][0]']
#
#  dense_1 (Dense)                (None, 8)            40          ['m_mo_e[0][1]']
#
#  income (Dense)                 (None, 2)            18          ['dense[0][0]']
#
#  marital (Dense)                (None, 2)            18          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 24,116
# Trainable params: 24,116
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(
  x=train_data,
  y=train_label,
  validation_data=(validation_data, validation_label),
  callbacks=[
    ROCCallback(
      training_data=(train_data, train_label),
      validation_data=(validation_data, validation_label),
      test_data=(test_data, test_label)
    )
  ],
  epochs=100
)
# Out:
# Epoch 1/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9083 ROC-AUC-income-Validation: 0.9089 ROC-AUC-income-Test: 0.9084
# ROC-AUC-marital-Train: 0.9671 ROC-AUC-marital-Validation: 0.9537 ROC-AUC-marital-Test: 0.9552
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.4701 - income_loss: 0.1835 - marital_loss: 0.2866 - income_accuracy: 0.9378 - marital_accuracy: 0.8953 - val_loss: 0.4522 - val_income_loss: 0.1640 - val_marital_loss: 0.2882 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.8738
# Epoch 2/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 5s 3ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9172 ROC-AUC-income-Validation: 0.9156 ROC-AUC-income-Test: 0.9156
# ROC-AUC-marital-Train: 0.9868 ROC-AUC-marital-Validation: 0.9718 ROC-AUC-marital-Test: 0.9714
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.3052 - income_loss: 0.1526 - marital_loss: 0.1526 - income_accuracy: 0.9379 - marital_accuracy: 0.9407 - val_loss: 0.3583 - val_income_loss: 0.1496 - val_marital_loss: 0.2086 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9173
# Epoch 3/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9179 ROC-AUC-income-Validation: 0.9159 ROC-AUC-income-Test: 0.9155
# ROC-AUC-marital-Train: 0.9897 ROC-AUC-marital-Validation: 0.9747 ROC-AUC-marital-Test: 0.9738
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2815 - income_loss: 0.1500 - marital_loss: 0.1315 - income_accuracy: 0.9379 - marital_accuracy: 0.9455 - val_loss: 0.3664 - val_income_loss: 0.1648 - val_marital_loss: 0.2016 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9173
# Epoch 4/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.914 ROC-AUC-income-Validation: 0.9152 ROC-AUC-income-Test: 0.916
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9744 ROC-AUC-marital-Test: 0.9739
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2710 - income_loss: 0.1462 - marital_loss: 0.1249 - income_accuracy: 0.9379 - marital_accuracy: 0.9477 - val_loss: 0.3798 - val_income_loss: 0.1496 - val_marital_loss: 0.2301 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9078
# Epoch 5/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9276 ROC-AUC-income-Validation: 0.9254 ROC-AUC-income-Test: 0.9237
# ROC-AUC-marital-Train: 0.9895 ROC-AUC-marital-Validation: 0.9711 ROC-AUC-marital-Test: 0.9709
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2681 - income_loss: 0.1457 - marital_loss: 0.1224 - income_accuracy: 0.9379 - marital_accuracy: 0.9485 - val_loss: 0.4240 - val_income_loss: 0.1773 - val_marital_loss: 0.2467 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9079
# Epoch 6/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9302 ROC-AUC-income-Validation: 0.928 ROC-AUC-income-Test: 0.9265
# ROC-AUC-marital-Train: 0.9883 ROC-AUC-marital-Validation: 0.9691 ROC-AUC-marital-Test: 0.9681
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2641 - income_loss: 0.1424 - marital_loss: 0.1217 - income_accuracy: 0.9380 - marital_accuracy: 0.9487 - val_loss: 0.4375 - val_income_loss: 0.1635 - val_marital_loss: 0.2740 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9057
# Epoch 7/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9227 ROC-AUC-income-Validation: 0.9196 ROC-AUC-income-Test: 0.9192
# ROC-AUC-marital-Train: 0.9906 ROC-AUC-marital-Validation: 0.9742 ROC-AUC-marital-Test: 0.9736
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2651 - income_loss: 0.1419 - marital_loss: 0.1233 - income_accuracy: 0.9380 - marital_accuracy: 0.9486 - val_loss: 0.3882 - val_income_loss: 0.1666 - val_marital_loss: 0.2217 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9139
# Epoch 8/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9321 ROC-AUC-income-Validation: 0.9295 ROC-AUC-income-Test: 0.9282
# ROC-AUC-marital-Train: 0.9897 ROC-AUC-marital-Validation: 0.9686 ROC-AUC-marital-Test: 0.9681
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2608 - income_loss: 0.1412 - marital_loss: 0.1196 - income_accuracy: 0.9379 - marital_accuracy: 0.9491 - val_loss: 0.3953 - val_income_loss: 0.1641 - val_marital_loss: 0.2312 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9092
# Epoch 9/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9367 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9738 ROC-AUC-marital-Test: 0.973
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2577 - income_loss: 0.1407 - marital_loss: 0.1170 - income_accuracy: 0.9393 - marital_accuracy: 0.9496 - val_loss: 0.3876 - val_income_loss: 0.1467 - val_marital_loss: 0.2409 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.9081
# Epoch 10/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9288 ROC-AUC-income-Validation: 0.9264 ROC-AUC-income-Test: 0.926
# ROC-AUC-marital-Train: 0.9911 ROC-AUC-marital-Validation: 0.9701 ROC-AUC-marital-Test: 0.9694
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2531 - income_loss: 0.1364 - marital_loss: 0.1168 - income_accuracy: 0.9413 - marital_accuracy: 0.9498 - val_loss: 0.3836 - val_income_loss: 0.1482 - val_marital_loss: 0.2354 - val_income_accuracy: 0.9314 - val_marital_accuracy: 0.9096
# Epoch 11/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9411 ROC-AUC-income-Validation: 0.9394 ROC-AUC-income-Test: 0.9381
# ROC-AUC-marital-Train: 0.991 ROC-AUC-marital-Validation: 0.968 ROC-AUC-marital-Test: 0.9672
# 6236/6236 [==============================] - 49s 8ms/step - loss: 0.2523 - income_loss: 0.1381 - marital_loss: 0.1142 - income_accuracy: 0.9397 - marital_accuracy: 0.9502 - val_loss: 0.4095 - val_income_loss: 0.1708 - val_marital_loss: 0.2386 - val_income_accuracy: 0.9466 - val_marital_accuracy: 0.9052
# Epoch 12/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.939 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9348
# ROC-AUC-marital-Train: 0.9908 ROC-AUC-marital-Validation: 0.9678 ROC-AUC-marital-Test: 0.9672
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2513 - income_loss: 0.1384 - marital_loss: 0.1129 - income_accuracy: 0.9386 - marital_accuracy: 0.9506 - val_loss: 0.4493 - val_income_loss: 0.1926 - val_marital_loss: 0.2567 - val_income_accuracy: 0.9454 - val_marital_accuracy: 0.9060
# Epoch 13/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 5s 3ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9345 ROC-AUC-income-Validation: 0.9331 ROC-AUC-income-Test: 0.9314
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9721 ROC-AUC-marital-Test: 0.9713
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2488 - income_loss: 0.1383 - marital_loss: 0.1105 - income_accuracy: 0.9397 - marital_accuracy: 0.9534 - val_loss: 0.3723 - val_income_loss: 0.1506 - val_marital_loss: 0.2217 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.9121
# Epoch 14/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.941 ROC-AUC-income-Validation: 0.9381 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.971 ROC-AUC-marital-Test: 0.9702
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2412 - income_loss: 0.1353 - marital_loss: 0.1059 - income_accuracy: 0.9442 - marital_accuracy: 0.9547 - val_loss: 0.4028 - val_income_loss: 0.1724 - val_marital_loss: 0.2304 - val_income_accuracy: 0.9455 - val_marital_accuracy: 0.9086
# Epoch 15/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.9365
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9706 ROC-AUC-marital-Test: 0.97
# 6236/6236 [==============================] - 52s 8ms/step - loss: 0.2383 - income_loss: 0.1338 - marital_loss: 0.1045 - income_accuracy: 0.9453 - marital_accuracy: 0.9555 - val_loss: 0.4076 - val_income_loss: 0.1758 - val_marital_loss: 0.2317 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.9087
# Epoch 16/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9701 ROC-AUC-marital-Test: 0.9694
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2406 - income_loss: 0.1329 - marital_loss: 0.1077 - income_accuracy: 0.9469 - marital_accuracy: 0.9547 - val_loss: 0.4240 - val_income_loss: 0.1899 - val_marital_loss: 0.2341 - val_income_accuracy: 0.9429 - val_marital_accuracy: 0.9052
# Epoch 17/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9362 ROC-AUC-income-Validation: 0.9332 ROC-AUC-income-Test: 0.9313
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9701 ROC-AUC-marital-Test: 0.9691
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2365 - income_loss: 0.1329 - marital_loss: 0.1036 - income_accuracy: 0.9455 - marital_accuracy: 0.9555 - val_loss: 0.4122 - val_income_loss: 0.1527 - val_marital_loss: 0.2595 - val_income_accuracy: 0.9446 - val_marital_accuracy: 0.9015
# Epoch 18/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.942 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9703 ROC-AUC-marital-Test: 0.9692
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2366 - income_loss: 0.1327 - marital_loss: 0.1039 - income_accuracy: 0.9462 - marital_accuracy: 0.9552 - val_loss: 0.4163 - val_income_loss: 0.1731 - val_marital_loss: 0.2432 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.9070
# Epoch 19/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.9393 ROC-AUC-income-Test: 0.9383
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9707 ROC-AUC-marital-Test: 0.9699
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2382 - income_loss: 0.1343 - marital_loss: 0.1039 - income_accuracy: 0.9447 - marital_accuracy: 0.9557 - val_loss: 0.3943 - val_income_loss: 0.1606 - val_marital_loss: 0.2337 - val_income_accuracy: 0.9458 - val_marital_accuracy: 0.9056
# Epoch 20/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9418 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9374
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9694 ROC-AUC-marital-Test: 0.9684
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2375 - income_loss: 0.1338 - marital_loss: 0.1037 - income_accuracy: 0.9465 - marital_accuracy: 0.9561 - val_loss: 0.4299 - val_income_loss: 0.1891 - val_marital_loss: 0.2408 - val_income_accuracy: 0.9439 - val_marital_accuracy: 0.9059
# Epoch 21/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9374 ROC-AUC-income-Validation: 0.9331 ROC-AUC-income-Test: 0.9325
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9691 ROC-AUC-marital-Test: 0.9681
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2359 - income_loss: 0.1338 - marital_loss: 0.1021 - income_accuracy: 0.9443 - marital_accuracy: 0.9559 - val_loss: 0.4147 - val_income_loss: 0.1705 - val_marital_loss: 0.2442 - val_income_accuracy: 0.9446 - val_marital_accuracy: 0.9031
# Epoch 22/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9925 ROC-AUC-marital-Validation: 0.9666 ROC-AUC-marital-Test: 0.9658
# 6236/6236 [==============================] - 52s 8ms/step - loss: 0.2354 - income_loss: 0.1330 - marital_loss: 0.1024 - income_accuracy: 0.9460 - marital_accuracy: 0.9563 - val_loss: 0.4373 - val_income_loss: 0.1777 - val_marital_loss: 0.2596 - val_income_accuracy: 0.9449 - val_marital_accuracy: 0.9028
# Epoch 23/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9356 ROC-AUC-income-Validation: 0.9323 ROC-AUC-income-Test: 0.9306
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9683 ROC-AUC-marital-Test: 0.9673
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2354 - income_loss: 0.1336 - marital_loss: 0.1018 - income_accuracy: 0.9451 - marital_accuracy: 0.9560 - val_loss: 0.4325 - val_income_loss: 0.1806 - val_marital_loss: 0.2518 - val_income_accuracy: 0.9408 - val_marital_accuracy: 0.9037
# Epoch 24/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9382 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9671 ROC-AUC-marital-Test: 0.9659
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2332 - income_loss: 0.1323 - marital_loss: 0.1008 - income_accuracy: 0.9473 - marital_accuracy: 0.9561 - val_loss: 0.4432 - val_income_loss: 0.1859 - val_marital_loss: 0.2573 - val_income_accuracy: 0.9452 - val_marital_accuracy: 0.9008
# Epoch 25/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9429 ROC-AUC-income-Validation: 0.9387 ROC-AUC-income-Test: 0.9382
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9681 ROC-AUC-marital-Test: 0.9672
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2335 - income_loss: 0.1323 - marital_loss: 0.1012 - income_accuracy: 0.9468 - marital_accuracy: 0.9564 - val_loss: 0.4393 - val_income_loss: 0.1720 - val_marital_loss: 0.2672 - val_income_accuracy: 0.9450 - val_marital_accuracy: 0.9014
# Epoch 26/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.9371 ROC-AUC-income-Test: 0.9359
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9674 ROC-AUC-marital-Test: 0.9662
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2341 - income_loss: 0.1329 - marital_loss: 0.1012 - income_accuracy: 0.9464 - marital_accuracy: 0.9562 - val_loss: 0.4312 - val_income_loss: 0.1752 - val_marital_loss: 0.2560 - val_income_accuracy: 0.9461 - val_marital_accuracy: 0.8998
# Epoch 27/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9425 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9368
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9662 ROC-AUC-marital-Test: 0.9654
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2312 - income_loss: 0.1310 - marital_loss: 0.1001 - income_accuracy: 0.9487 - marital_accuracy: 0.9563 - val_loss: 0.4481 - val_income_loss: 0.1778 - val_marital_loss: 0.2704 - val_income_accuracy: 0.9437 - val_marital_accuracy: 0.8996
# Epoch 28/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9277 ROC-AUC-income-Validation: 0.9206 ROC-AUC-income-Test: 0.9185
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9654 ROC-AUC-marital-Test: 0.9644
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2326 - income_loss: 0.1320 - marital_loss: 0.1006 - income_accuracy: 0.9470 - marital_accuracy: 0.9571 - val_loss: 0.4599 - val_income_loss: 0.1925 - val_marital_loss: 0.2673 - val_income_accuracy: 0.9444 - val_marital_accuracy: 0.8916
# Epoch 29/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9356 ROC-AUC-income-Validation: 0.9303 ROC-AUC-income-Test: 0.9297
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.9631
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2315 - income_loss: 0.1317 - marital_loss: 0.0999 - income_accuracy: 0.9473 - marital_accuracy: 0.9566 - val_loss: 0.4572 - val_income_loss: 0.1853 - val_marital_loss: 0.2719 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.8951
# Epoch 30/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.942 ROC-AUC-income-Validation: 0.9371 ROC-AUC-income-Test: 0.9351
# ROC-AUC-marital-Train: 0.992 ROC-AUC-marital-Validation: 0.9664 ROC-AUC-marital-Test: 0.9659
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2361 - income_loss: 0.1321 - marital_loss: 0.1040 - income_accuracy: 0.9477 - marital_accuracy: 0.9571 - val_loss: 0.4725 - val_income_loss: 0.1998 - val_marital_loss: 0.2727 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.9018
# Epoch 31/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9434 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9381
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9666 ROC-AUC-marital-Test: 0.9656
# 6236/6236 [==============================] - 49s 8ms/step - loss: 0.2310 - income_loss: 0.1309 - marital_loss: 0.1002 - income_accuracy: 0.9480 - marital_accuracy: 0.9573 - val_loss: 0.4511 - val_income_loss: 0.1840 - val_marital_loss: 0.2672 - val_income_accuracy: 0.9457 - val_marital_accuracy: 0.8980
# Epoch 32/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9377 ROC-AUC-income-Validation: 0.9261 ROC-AUC-income-Test: 0.9251
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9663 ROC-AUC-marital-Test: 0.9652
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2329 - income_loss: 0.1331 - marital_loss: 0.0998 - income_accuracy: 0.9486 - marital_accuracy: 0.9568 - val_loss: 0.4429 - val_income_loss: 0.1722 - val_marital_loss: 0.2707 - val_income_accuracy: 0.9403 - val_marital_accuracy: 0.8943
# Epoch 33/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9402 ROC-AUC-income-Validation: 0.9276 ROC-AUC-income-Test: 0.9274
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9654 ROC-AUC-marital-Test: 0.9647
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2318 - income_loss: 0.1327 - marital_loss: 0.0991 - income_accuracy: 0.9480 - marital_accuracy: 0.9569 - val_loss: 0.4390 - val_income_loss: 0.1698 - val_marital_loss: 0.2692 - val_income_accuracy: 0.9440 - val_marital_accuracy: 0.8973
# Epoch 34/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9389 ROC-AUC-income-Validation: 0.932 ROC-AUC-income-Test: 0.9311
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9658 ROC-AUC-marital-Test: 0.9648
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2347 - income_loss: 0.1338 - marital_loss: 0.1010 - income_accuracy: 0.9478 - marital_accuracy: 0.9568 - val_loss: 0.4381 - val_income_loss: 0.1743 - val_marital_loss: 0.2638 - val_income_accuracy: 0.9425 - val_marital_accuracy: 0.8942
# Epoch 35/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.941 ROC-AUC-income-Validation: 0.9257 ROC-AUC-income-Test: 0.926
# ROC-AUC-marital-Train: 0.9917 ROC-AUC-marital-Validation: 0.9645 ROC-AUC-marital-Test: 0.9632
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2315 - income_loss: 0.1322 - marital_loss: 0.0994 - income_accuracy: 0.9487 - marital_accuracy: 0.9572 - val_loss: 0.4612 - val_income_loss: 0.1861 - val_marital_loss: 0.2751 - val_income_accuracy: 0.9454 - val_marital_accuracy: 0.8955
# Epoch 36/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9323 ROC-AUC-income-Test: 0.9315
# ROC-AUC-marital-Train: 0.9898 ROC-AUC-marital-Validation: 0.9609 ROC-AUC-marital-Test: 0.9601
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2313 - income_loss: 0.1320 - marital_loss: 0.0993 - income_accuracy: 0.9480 - marital_accuracy: 0.9570 - val_loss: 0.4883 - val_income_loss: 0.2044 - val_marital_loss: 0.2839 - val_income_accuracy: 0.9406 - val_marital_accuracy: 0.8936
# Epoch 37/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9411 ROC-AUC-income-Validation: 0.9283 ROC-AUC-income-Test: 0.9269
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9638
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2308 - income_loss: 0.1320 - marital_loss: 0.0989 - income_accuracy: 0.9487 - marital_accuracy: 0.9570 - val_loss: 0.4862 - val_income_loss: 0.2058 - val_marital_loss: 0.2804 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.8948
# Epoch 38/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9385 ROC-AUC-income-Validation: 0.9293 ROC-AUC-income-Test: 0.929
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.963
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2311 - income_loss: 0.1322 - marital_loss: 0.0988 - income_accuracy: 0.9475 - marital_accuracy: 0.9571 - val_loss: 0.4550 - val_income_loss: 0.1838 - val_marital_loss: 0.2712 - val_income_accuracy: 0.9380 - val_marital_accuracy: 0.8895
# Epoch 39/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9447 ROC-AUC-income-Validation: 0.9381 ROC-AUC-income-Test: 0.9373
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9626 ROC-AUC-marital-Test: 0.9614
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2298 - income_loss: 0.1312 - marital_loss: 0.0986 - income_accuracy: 0.9470 - marital_accuracy: 0.9576 - val_loss: 0.4736 - val_income_loss: 0.1917 - val_marital_loss: 0.2820 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8882
# Epoch 40/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9374 ROC-AUC-income-Validation: 0.9185 ROC-AUC-income-Test: 0.9198
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.963
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2306 - income_loss: 0.1325 - marital_loss: 0.0981 - income_accuracy: 0.9478 - marital_accuracy: 0.9573 - val_loss: 0.4643 - val_income_loss: 0.1708 - val_marital_loss: 0.2935 - val_income_accuracy: 0.9410 - val_marital_accuracy: 0.8939
# Epoch 41/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9385 ROC-AUC-income-Validation: 0.9342 ROC-AUC-income-Test: 0.9345
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.963
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2309 - income_loss: 0.1329 - marital_loss: 0.0980 - income_accuracy: 0.9477 - marital_accuracy: 0.9575 - val_loss: 0.4599 - val_income_loss: 0.1756 - val_marital_loss: 0.2843 - val_income_accuracy: 0.9399 - val_marital_accuracy: 0.8920
# Epoch 42/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9337 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9299
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9619
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2294 - income_loss: 0.1314 - marital_loss: 0.0980 - income_accuracy: 0.9476 - marital_accuracy: 0.9573 - val_loss: 0.4658 - val_income_loss: 0.1882 - val_marital_loss: 0.2776 - val_income_accuracy: 0.9410 - val_marital_accuracy: 0.8868
# Epoch 43/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9423 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9643 ROC-AUC-marital-Test: 0.9633
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2289 - income_loss: 0.1300 - marital_loss: 0.0989 - income_accuracy: 0.9479 - marital_accuracy: 0.9572 - val_loss: 0.4565 - val_income_loss: 0.1697 - val_marital_loss: 0.2868 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8943
# Epoch 44/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9269 ROC-AUC-income-Test: 0.9256
# ROC-AUC-marital-Train: 0.9933 ROC-AUC-marital-Validation: 0.9595 ROC-AUC-marital-Test: 0.9584
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2289 - income_loss: 0.1314 - marital_loss: 0.0975 - income_accuracy: 0.9487 - marital_accuracy: 0.9580 - val_loss: 0.5139 - val_income_loss: 0.2096 - val_marital_loss: 0.3044 - val_income_accuracy: 0.9439 - val_marital_accuracy: 0.8816
# Epoch 45/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9399 ROC-AUC-income-Validation: 0.9292 ROC-AUC-income-Test: 0.9274
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9621 ROC-AUC-marital-Test: 0.9612
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2273 - income_loss: 0.1297 - marital_loss: 0.0976 - income_accuracy: 0.9483 - marital_accuracy: 0.9573 - val_loss: 0.4704 - val_income_loss: 0.1748 - val_marital_loss: 0.2956 - val_income_accuracy: 0.9394 - val_marital_accuracy: 0.8925
# Epoch 46/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 5s 3ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9382 ROC-AUC-income-Validation: 0.9301 ROC-AUC-income-Test: 0.9291
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9614 ROC-AUC-marital-Test: 0.9601
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2265 - income_loss: 0.1287 - marital_loss: 0.0978 - income_accuracy: 0.9501 - marital_accuracy: 0.9575 - val_loss: 0.4895 - val_income_loss: 0.1895 - val_marital_loss: 0.3000 - val_income_accuracy: 0.9438 - val_marital_accuracy: 0.8869
# Epoch 47/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.9289 ROC-AUC-income-Test: 0.9283
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9562 ROC-AUC-marital-Test: 0.9553
# 6236/6236 [==============================] - 49s 8ms/step - loss: 0.2299 - income_loss: 0.1323 - marital_loss: 0.0976 - income_accuracy: 0.9475 - marital_accuracy: 0.9574 - val_loss: 0.5243 - val_income_loss: 0.2057 - val_marital_loss: 0.3186 - val_income_accuracy: 0.9424 - val_marital_accuracy: 0.8777
# Epoch 48/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9456 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9353
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.961 ROC-AUC-marital-Test: 0.9598
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2257 - income_loss: 0.1279 - marital_loss: 0.0978 - income_accuracy: 0.9498 - marital_accuracy: 0.9578 - val_loss: 0.4912 - val_income_loss: 0.1885 - val_marital_loss: 0.3026 - val_income_accuracy: 0.9437 - val_marital_accuracy: 0.8873
# Epoch 49/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9451 ROC-AUC-income-Validation: 0.9317 ROC-AUC-income-Test: 0.9327
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9592 ROC-AUC-marital-Test: 0.9579
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2278 - income_loss: 0.1288 - marital_loss: 0.0990 - income_accuracy: 0.9497 - marital_accuracy: 0.9573 - val_loss: 0.5087 - val_income_loss: 0.1950 - val_marital_loss: 0.3137 - val_income_accuracy: 0.9442 - val_marital_accuracy: 0.8849
# Epoch 50/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9307 ROC-AUC-income-Test: 0.9307
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9593 ROC-AUC-marital-Test: 0.9579
# 6236/6236 [==============================] - 52s 8ms/step - loss: 0.2296 - income_loss: 0.1315 - marital_loss: 0.0981 - income_accuracy: 0.9478 - marital_accuracy: 0.9580 - val_loss: 0.5053 - val_income_loss: 0.1973 - val_marital_loss: 0.3080 - val_income_accuracy: 0.9424 - val_marital_accuracy: 0.8831
# Epoch 51/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.942 ROC-AUC-income-Validation: 0.9332 ROC-AUC-income-Test: 0.9322
# ROC-AUC-marital-Train: 0.9912 ROC-AUC-marital-Validation: 0.9595 ROC-AUC-marital-Test: 0.9584
# 6236/6236 [==============================] - 52s 8ms/step - loss: 0.2297 - income_loss: 0.1301 - marital_loss: 0.0996 - income_accuracy: 0.9488 - marital_accuracy: 0.9577 - val_loss: 0.4761 - val_income_loss: 0.1924 - val_marital_loss: 0.2837 - val_income_accuracy: 0.9450 - val_marital_accuracy: 0.8869
# Epoch 52/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9371 ROC-AUC-income-Validation: 0.9282 ROC-AUC-income-Test: 0.9269
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9622 ROC-AUC-marital-Test: 0.961
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2282 - income_loss: 0.1301 - marital_loss: 0.0981 - income_accuracy: 0.9479 - marital_accuracy: 0.9579 - val_loss: 0.4843 - val_income_loss: 0.1897 - val_marital_loss: 0.2946 - val_income_accuracy: 0.9395 - val_marital_accuracy: 0.8880
# Epoch 53/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.943 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9349
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.961 ROC-AUC-marital-Test: 0.9601
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2279 - income_loss: 0.1302 - marital_loss: 0.0977 - income_accuracy: 0.9486 - marital_accuracy: 0.9576 - val_loss: 0.4695 - val_income_loss: 0.1879 - val_marital_loss: 0.2816 - val_income_accuracy: 0.9437 - val_marital_accuracy: 0.8881
# Epoch 54/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9455 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9598
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2306 - income_loss: 0.1296 - marital_loss: 0.1010 - income_accuracy: 0.9482 - marital_accuracy: 0.9579 - val_loss: 0.4819 - val_income_loss: 0.1905 - val_marital_loss: 0.2914 - val_income_accuracy: 0.9438 - val_marital_accuracy: 0.8867
# Epoch 55/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9316 ROC-AUC-income-Test: 0.9309
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9614 ROC-AUC-marital-Test: 0.9604
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2302 - income_loss: 0.1293 - marital_loss: 0.1009 - income_accuracy: 0.9498 - marital_accuracy: 0.9576 - val_loss: 0.5238 - val_income_loss: 0.2224 - val_marital_loss: 0.3014 - val_income_accuracy: 0.9433 - val_marital_accuracy: 0.8898
# Epoch 56/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9316 ROC-AUC-income-Validation: 0.9235 ROC-AUC-income-Test: 0.923
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9622
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2297 - income_loss: 0.1292 - marital_loss: 0.1005 - income_accuracy: 0.9485 - marital_accuracy: 0.9575 - val_loss: 0.4905 - val_income_loss: 0.1833 - val_marital_loss: 0.3072 - val_income_accuracy: 0.9417 - val_marital_accuracy: 0.8919
# Epoch 57/100
# 6236/6236 [==============================] - 15s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9404 ROC-AUC-income-Validation: 0.9287 ROC-AUC-income-Test: 0.9288
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9608 ROC-AUC-marital-Test: 0.9599
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2314 - income_loss: 0.1314 - marital_loss: 0.1000 - income_accuracy: 0.9480 - marital_accuracy: 0.9573 - val_loss: 0.4984 - val_income_loss: 0.1975 - val_marital_loss: 0.3010 - val_income_accuracy: 0.9441 - val_marital_accuracy: 0.8897
# Epoch 58/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9422 ROC-AUC-income-Validation: 0.9238 ROC-AUC-income-Test: 0.9247
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9594 ROC-AUC-marital-Test: 0.9583
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2269 - income_loss: 0.1284 - marital_loss: 0.0985 - income_accuracy: 0.9495 - marital_accuracy: 0.9579 - val_loss: 0.5559 - val_income_loss: 0.2531 - val_marital_loss: 0.3028 - val_income_accuracy: 0.9397 - val_marital_accuracy: 0.8856
# Epoch 59/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9441 ROC-AUC-income-Validation: 0.9281 ROC-AUC-income-Test: 0.9274
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9606 ROC-AUC-marital-Test: 0.9595
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2260 - income_loss: 0.1272 - marital_loss: 0.0988 - income_accuracy: 0.9512 - marital_accuracy: 0.9573 - val_loss: 0.5304 - val_income_loss: 0.2070 - val_marital_loss: 0.3234 - val_income_accuracy: 0.9433 - val_marital_accuracy: 0.8891
# Epoch 60/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9385 ROC-AUC-income-Validation: 0.9288 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9583 ROC-AUC-marital-Test: 0.9569
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2275 - income_loss: 0.1280 - marital_loss: 0.0994 - income_accuracy: 0.9501 - marital_accuracy: 0.9575 - val_loss: 0.4943 - val_income_loss: 0.1856 - val_marital_loss: 0.3087 - val_income_accuracy: 0.9387 - val_marital_accuracy: 0.8852
# Epoch 61/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9212 ROC-AUC-income-Validation: 0.9227 ROC-AUC-income-Test: 0.9206
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9581 ROC-AUC-marital-Test: 0.9567
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2299 - income_loss: 0.1312 - marital_loss: 0.0987 - income_accuracy: 0.9461 - marital_accuracy: 0.9574 - val_loss: 0.5149 - val_income_loss: 0.1988 - val_marital_loss: 0.3161 - val_income_accuracy: 0.9393 - val_marital_accuracy: 0.8852
# Epoch 62/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9438 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9352
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9586 ROC-AUC-marital-Test: 0.9575
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2252 - income_loss: 0.1271 - marital_loss: 0.0981 - income_accuracy: 0.9503 - marital_accuracy: 0.9576 - val_loss: 0.4927 - val_income_loss: 0.1881 - val_marital_loss: 0.3046 - val_income_accuracy: 0.9455 - val_marital_accuracy: 0.8858
# Epoch 63/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9459 ROC-AUC-income-Validation: 0.9333 ROC-AUC-income-Test: 0.9327
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9574 ROC-AUC-marital-Test: 0.9562
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2258 - income_loss: 0.1271 - marital_loss: 0.0987 - income_accuracy: 0.9503 - marital_accuracy: 0.9573 - val_loss: 0.5281 - val_income_loss: 0.2126 - val_marital_loss: 0.3155 - val_income_accuracy: 0.9425 - val_marital_accuracy: 0.8869
# Epoch 64/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 4s 2ms/step
# 1559/1559 [==============================] - 4s 3ms/step
# ROC-AUC-income-Train: 0.9454 ROC-AUC-income-Validation: 0.9367 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9571 ROC-AUC-marital-Test: 0.9558
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2255 - income_loss: 0.1266 - marital_loss: 0.0989 - income_accuracy: 0.9511 - marital_accuracy: 0.9571 - val_loss: 0.5264 - val_income_loss: 0.2105 - val_marital_loss: 0.3159 - val_income_accuracy: 0.9432 - val_marital_accuracy: 0.8832
# Epoch 65/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.9334 ROC-AUC-income-Test: 0.9327
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9576 ROC-AUC-marital-Test: 0.9566
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2247 - income_loss: 0.1276 - marital_loss: 0.0971 - income_accuracy: 0.9509 - marital_accuracy: 0.9578 - val_loss: 0.5429 - val_income_loss: 0.2231 - val_marital_loss: 0.3198 - val_income_accuracy: 0.9423 - val_marital_accuracy: 0.8874
# Epoch 66/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9342 ROC-AUC-income-Test: 0.9344
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9576 ROC-AUC-marital-Test: 0.9564
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2239 - income_loss: 0.1274 - marital_loss: 0.0965 - income_accuracy: 0.9501 - marital_accuracy: 0.9581 - val_loss: 0.5102 - val_income_loss: 0.1984 - val_marital_loss: 0.3118 - val_income_accuracy: 0.9413 - val_marital_accuracy: 0.8854
# Epoch 67/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9449 ROC-AUC-income-Validation: 0.936 ROC-AUC-income-Test: 0.9362
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9581 ROC-AUC-marital-Test: 0.9569
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2249 - income_loss: 0.1279 - marital_loss: 0.0970 - income_accuracy: 0.9497 - marital_accuracy: 0.9579 - val_loss: 0.5135 - val_income_loss: 0.1883 - val_marital_loss: 0.3251 - val_income_accuracy: 0.9453 - val_marital_accuracy: 0.8889
# Epoch 68/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9422 ROC-AUC-income-Validation: 0.9325 ROC-AUC-income-Test: 0.9322
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.958 ROC-AUC-marital-Test: 0.9569
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2261 - income_loss: 0.1290 - marital_loss: 0.0971 - income_accuracy: 0.9487 - marital_accuracy: 0.9574 - val_loss: 0.5213 - val_income_loss: 0.2000 - val_marital_loss: 0.3213 - val_income_accuracy: 0.9389 - val_marital_accuracy: 0.8893
# Epoch 69/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.9326 ROC-AUC-income-Test: 0.9326
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9588 ROC-AUC-marital-Test: 0.9576
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2248 - income_loss: 0.1270 - marital_loss: 0.0978 - income_accuracy: 0.9504 - marital_accuracy: 0.9579 - val_loss: 0.5184 - val_income_loss: 0.2118 - val_marital_loss: 0.3066 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.8902
# Epoch 70/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9407 ROC-AUC-income-Validation: 0.9326 ROC-AUC-income-Test: 0.9324
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9574 ROC-AUC-marital-Test: 0.956
# 6236/6236 [==============================] - 50s 8ms/step - loss: 0.2251 - income_loss: 0.1283 - marital_loss: 0.0968 - income_accuracy: 0.9507 - marital_accuracy: 0.9582 - val_loss: 0.5035 - val_income_loss: 0.1974 - val_marital_loss: 0.3061 - val_income_accuracy: 0.9446 - val_marital_accuracy: 0.8846
# Epoch 71/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9399 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9295
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9574 ROC-AUC-marital-Test: 0.9561
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2247 - income_loss: 0.1286 - marital_loss: 0.0962 - income_accuracy: 0.9499 - marital_accuracy: 0.9580 - val_loss: 0.5077 - val_income_loss: 0.2037 - val_marital_loss: 0.3041 - val_income_accuracy: 0.9436 - val_marital_accuracy: 0.8858
# Epoch 72/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ...
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9351
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9578 ROC-AUC-marital-Test: 0.9565
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2232 - income_loss: 0.1259 - marital_loss: 0.0973 - income_accuracy: 0.9514 - marital_accuracy: 0.9581 - val_loss: 0.5318 - val_income_loss: 0.2239 - val_marital_loss: 0.3078 - val_income_accuracy: 0.9440 - val_marital_accuracy: 0.8897
# Epoch 78/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9451 ROC-AUC-income-Validation: 0.9337 ROC-AUC-income-Test: 0.9337
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9569 ROC-AUC-marital-Test: 0.9556
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2232 - income_loss: 0.1269 - marital_loss: 0.0963 - income_accuracy: 0.9511 - marital_accuracy: 0.9580 - val_loss: 0.5362 - val_income_loss: 0.2324 - val_marital_loss: 0.3038 - val_income_accuracy: 0.9406 - val_marital_accuracy: 0.8880
# Epoch 79/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9455 ROC-AUC-income-Validation: 0.9348 ROC-AUC-income-Test: 0.935
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.956 ROC-AUC-marital-Test: 0.9549
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2231 - income_loss: 0.1264 - marital_loss: 0.0967 - income_accuracy: 0.9514 - marital_accuracy: 0.9580 - val_loss: 0.5421 - val_income_loss: 0.2322 - val_marital_loss: 0.3099 - val_income_accuracy: 0.9415 - val_marital_accuracy: 0.8897
# Epoch 80/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9449 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9535 ROC-AUC-marital-Test: 0.9524
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2217 - income_loss: 0.1250 - marital_loss: 0.0967 - income_accuracy: 0.9515 - marital_accuracy: 0.9578 - val_loss: 0.5816 - val_income_loss: 0.2036 - val_marital_loss: 0.3780 - val_income_accuracy: 0.9458 - val_marital_accuracy: 0.8907
# Epoch 81/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9551 ROC-AUC-marital-Test: 0.954
# 6236/6236 [==============================] - 53s 8ms/step - loss: 0.2220 - income_loss: 0.1264 - marital_loss: 0.0956 - income_accuracy: 0.9507 - marital_accuracy: 0.9584 - val_loss: 0.5564 - val_income_loss: 0.1916 - val_marital_loss: 0.3648 - val_income_accuracy: 0.9453 - val_marital_accuracy: 0.8930
# Epoch 82/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 4s 3ms/step
# 1559/1559 [==============================] - 4s 3ms/step
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9351 ROC-AUC-income-Test: 0.9347
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9545 ROC-AUC-marital-Test: 0.9534
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2238 - income_loss: 0.1275 - marital_loss: 0.0963 - income_accuracy: 0.9508 - marital_accuracy: 0.9582 - val_loss: 0.5029 - val_income_loss: 0.1847 - val_marital_loss: 0.3182 - val_income_accuracy: 0.9445 - val_marital_accuracy: 0.8891
# Epoch 83/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9455 ROC-AUC-income-Validation: 0.9345 ROC-AUC-income-Test: 0.9347
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9535 ROC-AUC-marital-Test: 0.9524
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2238 - income_loss: 0.1271 - marital_loss: 0.0967 - income_accuracy: 0.9503 - marital_accuracy: 0.9578 - val_loss: 0.5561 - val_income_loss: 0.2343 - val_marital_loss: 0.3217 - val_income_accuracy: 0.9425 - val_marital_accuracy: 0.8918
# Epoch 84/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9556 ROC-AUC-marital-Test: 0.9544
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2214 - income_loss: 0.1257 - marital_loss: 0.0957 - income_accuracy: 0.9517 - marital_accuracy: 0.9581 - val_loss: 0.5406 - val_income_loss: 0.1943 - val_marital_loss: 0.3463 - val_income_accuracy: 0.9438 - val_marital_accuracy: 0.8935
# Epoch 85/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9449 ROC-AUC-income-Validation: 0.9343 ROC-AUC-income-Test: 0.9347
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9555 ROC-AUC-marital-Test: 0.9544
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2217 - income_loss: 0.1253 - marital_loss: 0.0964 - income_accuracy: 0.9516 - marital_accuracy: 0.9580 - val_loss: 0.5742 - val_income_loss: 0.2476 - val_marital_loss: 0.3266 - val_income_accuracy: 0.9430 - val_marital_accuracy: 0.8923
# Epoch 86/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9542 ROC-AUC-marital-Test: 0.9533
# 6236/6236 [==============================] - 51s 8ms/step - loss: 0.2207 - income_loss: 0.1251 - marital_loss: 0.0955 - income_accuracy: 0.9517 - marital_accuracy: 0.9581 - val_loss: 0.5593 - val_income_loss: 0.2277 - val_marital_loss: 0.3317 - val_income_accuracy: 0.9444 - val_marital_accuracy: 0.8927
# Epoch 87/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9443 ROC-AUC-income-Validation: 0.9325 ROC-AUC-income-Test: 0.9322
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9545 ROC-AUC-marital-Test: 0.9534
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2212 - income_loss: 0.1262 - marital_loss: 0.0949 - income_accuracy: 0.9510 - marital_accuracy: 0.9586 - val_loss: 0.5551 - val_income_loss: 0.2259 - val_marital_loss: 0.3292 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.8936
# Epoch 88/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9357
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9542 ROC-AUC-marital-Test: 0.953
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2228 - income_loss: 0.1264 - marital_loss: 0.0964 - income_accuracy: 0.9505 - marital_accuracy: 0.9588 - val_loss: 0.5555 - val_income_loss: 0.2182 - val_marital_loss: 0.3373 - val_income_accuracy: 0.9411 - val_marital_accuracy: 0.8936
# Epoch 89/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.9307 ROC-AUC-income-Test: 0.9319
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9535 ROC-AUC-marital-Test: 0.9521
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2230 - income_loss: 0.1269 - marital_loss: 0.0961 - income_accuracy: 0.9508 - marital_accuracy: 0.9583 - val_loss: 0.5462 - val_income_loss: 0.2075 - val_marital_loss: 0.3387 - val_income_accuracy: 0.9418 - val_marital_accuracy: 0.8908
# Epoch 90/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9356 ROC-AUC-income-Test: 0.9352
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.952 ROC-AUC-marital-Test: 0.9507
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2200 - income_loss: 0.1250 - marital_loss: 0.0950 - income_accuracy: 0.9516 - marital_accuracy: 0.9586 - val_loss: 0.5315 - val_income_loss: 0.2030 - val_marital_loss: 0.3285 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8859
# Epoch 91/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9289 ROC-AUC-income-Validation: 0.9209 ROC-AUC-income-Test: 0.9168
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9493 ROC-AUC-marital-Test: 0.9478
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2208 - income_loss: 0.1249 - marital_loss: 0.0959 - income_accuracy: 0.9517 - marital_accuracy: 0.9584 - val_loss: 0.5239 - val_income_loss: 0.1988 - val_marital_loss: 0.3251 - val_income_accuracy: 0.9389 - val_marital_accuracy: 0.8817
# Epoch 92/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9447 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9349
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9514 ROC-AUC-marital-Test: 0.95
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2203 - income_loss: 0.1246 - marital_loss: 0.0957 - income_accuracy: 0.9520 - marital_accuracy: 0.9585 - val_loss: 0.5135 - val_income_loss: 0.2042 - val_marital_loss: 0.3093 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.8804
# Epoch 93/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9456 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9349
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9499 ROC-AUC-marital-Test: 0.9484
# 6236/6236 [==============================] - 53s 9ms/step - loss: 0.2202 - income_loss: 0.1247 - marital_loss: 0.0955 - income_accuracy: 0.9516 - marital_accuracy: 0.9584 - val_loss: 0.5584 - val_income_loss: 0.2235 - val_marital_loss: 0.3349 - val_income_accuracy: 0.9409 - val_marital_accuracy: 0.8872
# Epoch 94/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9438 ROC-AUC-income-Validation: 0.9344 ROC-AUC-income-Test: 0.9336
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9484 ROC-AUC-marital-Test: 0.9469
# 6236/6236 [==============================] - 52s 8ms/step - loss: 0.2205 - income_loss: 0.1249 - marital_loss: 0.0957 - income_accuracy: 0.9515 - marital_accuracy: 0.9582 - val_loss: 0.5431 - val_income_loss: 0.2008 - val_marital_loss: 0.3424 - val_income_accuracy: 0.9455 - val_marital_accuracy: 0.8832
# Epoch 95/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 4s 3ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9463 ROC-AUC-income-Validation: 0.936 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9486 ROC-AUC-marital-Test: 0.9471
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2203 - income_loss: 0.1252 - marital_loss: 0.0951 - income_accuracy: 0.9515 - marital_accuracy: 0.9583 - val_loss: 0.5562 - val_income_loss: 0.2305 - val_marital_loss: 0.3258 - val_income_accuracy: 0.9434 - val_marital_accuracy: 0.8767
# Epoch 96/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9365 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9483 ROC-AUC-marital-Test: 0.9469
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2202 - income_loss: 0.1248 - marital_loss: 0.0954 - income_accuracy: 0.9515 - marital_accuracy: 0.9581 - val_loss: 0.5144 - val_income_loss: 0.1892 - val_marital_loss: 0.3252 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8801
# Epoch 97/100
# 6236/6236 [==============================] - 12s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.941 ROC-AUC-income-Validation: 0.9309 ROC-AUC-income-Test: 0.9314
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9504 ROC-AUC-marital-Test: 0.949
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2230 - income_loss: 0.1282 - marital_loss: 0.0948 - income_accuracy: 0.9488 - marital_accuracy: 0.9586 - val_loss: 0.5595 - val_income_loss: 0.2189 - val_marital_loss: 0.3406 - val_income_accuracy: 0.9447 - val_marital_accuracy: 0.8860
# Epoch 98/100
# 6236/6236 [==============================] - 14s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9365 ROC-AUC-income-Validation: 0.9258 ROC-AUC-income-Test: 0.9262
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9502 ROC-AUC-marital-Test: 0.9488
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2249 - income_loss: 0.1293 - marital_loss: 0.0956 - income_accuracy: 0.9485 - marital_accuracy: 0.9584 - val_loss: 0.5136 - val_income_loss: 0.2051 - val_marital_loss: 0.3085 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.8754
# Epoch 99/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9441 ROC-AUC-income-Validation: 0.9328 ROC-AUC-income-Test: 0.9331
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9471 ROC-AUC-marital-Test: 0.9455
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2232 - income_loss: 0.1276 - marital_loss: 0.0956 - income_accuracy: 0.9498 - marital_accuracy: 0.9580 - val_loss: 0.5790 - val_income_loss: 0.2349 - val_marital_loss: 0.3441 - val_income_accuracy: 0.9433 - val_marital_accuracy: 0.8827
# Epoch 100/100
# 6236/6236 [==============================] - 13s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# 1559/1559 [==============================] - 3s 2ms/step
# ROC-AUC-income-Train: 0.9449 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9353
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9481 ROC-AUC-marital-Test: 0.9468
# 6236/6236 [==============================] - 54s 9ms/step - loss: 0.2218 - income_loss: 0.1259 - marital_loss: 0.0959 - income_accuracy: 0.9509 - marital_accuracy: 0.9579 - val_loss: 0.5423 - val_income_loss: 0.2065 - val_marital_loss: 0.3358 - val_income_accuracy: 0.9444 - val_marital_accuracy: 0.8761

# %% [markdown]
# Copyright: [Drawbridge, Inc](https://github.com/drawbridge/keras-mmoe)

# %% [markdown]
# # Transfer Learning using head2toe

# %%
# !pip install ml-collections
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ml-collections
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 2.9 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from ml-collections) (1.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from ml-collections) (6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from ml-collections) (1.15.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from ml-collections) (0.5.5)
# Building wheels for collected packages: ml-collections
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94524 sha256=d00a16b741607cc602edce2c64f6992a8cb2c19ad86c9cb0adfeae9deccc9db3
#   Stored in directory: /root/.cache/pip/wheels/b7/da/64/33c926a1b10ff19791081b705879561b715a8341a856a3bbd2
# Successfully built ml-collections
# Installing collected packages: ml-collections
# Successfully installed ml-collections-0.1.1

# %%
import absl.testing.parameterized as parameterized
import tensorflow as tf
import tensorflow.compat.v2 as tf2
import re
from ml_collections import ConfigDict

# %%
def get_config(config_string):
  train_batch_size = 128
  eval_batch_size = 50
  config = ConfigDict({
      'dataset':
          'data.caltech101',
      'eval_mode':
          'valid',
      'is_vtab_5fold_valid':
          True,
      'seed':
          8,
      'max_num_gpus':
          1,
      'learning':
          ConfigDict({
              'optimizer': 'adam',  #  adadelta, adadelta_adaptive, sgd
              'learning_rate': 0.1,
              'grad_clip_value': -1.,  # Applied if positive.
              'l1_regularizer': 0.,
              'l2_regularizer': 0.,
              'group_lrp_regularizer_coef': 0.,
              'group_lrp_regularizer_r': 2.,
              'group_lrp_regularizer_p': 1.,
              'group_lrp_is_embedding': False,
              'training_steps': 500,
              'data_fraction': 1.,
              'cached_eval': True,
              'use_cosine_decay': True,
              'train_batch_size': train_batch_size,
              'eval_batch_size': eval_batch_size,
              'finetune_backbones': False,
              'finetune_lr_multiplier': 1.,
              'finetune_steps_multiplier': 1.,
              # ('', 'unit_vector', 'per_feature')
              'feature_normalization': 'unit_vector',
              # nohidden, random_100, random_1000, trainable_100, trainable_1000
              'output_head_type': 'nohidden',
              'output_head_zeroinit': False,
              'log_freq': 50,
          }),
      'model_name':
          'Finetune'
  })

  config.backbone = get_backbone_config(config_string)
  print(f'Config backbone: {config.backbone}')
  return config

# %%
def get_backbone_config(config_string):
  """Gets backbone configuration according to the key given."""
  # Example patterns:
  # imagenetr50, imagenetr50_2x
  pattern = r'^([A-Za-z0-9]+)?_?(\d+)?x?'
  searched = re.search(pattern, config_string)
  if not searched:
    raise ValueError(f'Unrecognized config_string: {config_string}')
  added_backbone, n_repeat = searched.groups()
  print(f'Split config: {added_backbone}, {n_repeat}')
  processed_names = []
  processed_handles = []
  processed_signatures = []
  processed_output_keys = []
  input_sizes = tuple()

  if added_backbone in SINGLE_MODELS:
    n_repeat = int(n_repeat) if n_repeat else 1
    processed_names += [added_backbone] * n_repeat
    handle, size = SINGLE_MODELS[added_backbone]
    if isinstance(handle, list):
      processed_handles = handle * n_repeat
      processed_handles = processed_handles[:n_repeat]
    else:
      processed_handles += [handle] * n_repeat

    if 'vit' in added_backbone:
      processed_signatures += ['serving_default'] * n_repeat
      processed_output_keys += ['pre_logits'] * n_repeat
    else:
      processed_signatures += ['representation'] * n_repeat
      processed_output_keys += ['pre_logits'] * n_repeat
    input_sizes += (size,) * n_repeat
  else:
    raise ValueError(f'added_backbone:{added_backbone} is not recognized')

  return ConfigDict({
      'names': processed_names,
      'handles': processed_handles,
      'signatures': processed_signatures,
      'output_keys': processed_output_keys,
      'input_sizes': input_sizes,
      'include_input': False,
      'additional_features': '',
      'additional_features_pool_size': 0,
      'cls_token_pool': 'normal',
      # If target size is provided, pool size is ignored.
      'additional_features_target_size': 0,
      'additional_features_multi_target_sizes': '',
  })

# %%
SINGLE_MODELS = {
    'imagenetr50': ('checkpoints/imagenetr50/', 240),
    'imagenetvitB16': ('checkpoints/imagenetvitB16/', 224)
}

# %%
def get_config_fs(config_string):
  config = finetune.get_config(config_string)
  config['model_name'] = 'FinetuneFS'
  new_learning_config = ConfigDict({
      'feature_selection':
          ConfigDict({
              # Following types exist: 'connectivity_mask',
              # 'connectivity_l1', 'random', 'none', 'variance' and
              # 'sklearn_x' where x in
              # [chi2, f_classif, mutual_info_classif, trees]
              'type': 'none',
              'fs_dataset': '',
              'is_overwrite': False,
              'average_over_k': 1,
              'keep_fraction': 0.1,
              'keep_fraction_offset': 0,
              'mean_interpolation_coef': 0.,
              'learning_config_overwrite':
                  ConfigDict({
                      'group_lrp_regularizer_coef': 1e-4,
                      'finetune_backbones': False,
                  })
          }),
  })
  config['learning'].update(new_learning_config)
  print(f'Config backbone: {config.backbone}')
  return config

# %%
def _filter_to_k_shot(dataset, num_classes, k):
  """Filters k-shot subset from a dataset."""
  # !!! IMPORTANT: the dataset should *not* be shuffled. !!!
  # Make sure that `shuffle_buffer_size=1` in the call to
  # `dloader.get_tf_data`.

  # Indices of included examples in the k-shot balanced dataset.
  keep_example = []
  # Keep track of the number of examples per class included in
  # `keep_example`.
  class_counts = np.zeros([num_classes], dtype=np.int32)
  for _, label in dataset.as_numpy_iterator():
    # If there are less than `k` examples of class `label` in `example_indices`,
    # keep this example and update the class counts.
    keep = class_counts[label] < k
    keep_example.append(keep)
    if keep:
      class_counts[label] += 1
    # When there are `k` examples for each class included in `keep_example`,
    # stop searching.
    if (class_counts == k).all():
      break

  dataset = tf.data.Dataset.zip((
      tf.data.Dataset.from_tensor_slices(keep_example),
      dataset
  )).filter(lambda keep, _: keep).map(lambda _, example: example).cache()

  return dataset

# %%
def create_vtab_dataset_balanced(dataset, image_size, batch_size,
                                 data_fraction):
  """Creates a VTAB input_fn to be used by `tf.Estimator`.

  Deterministic balanced sampling from vtab datasets.

  Args:
    dataset: str, VTAB task to evaluate on.
    image_size: int
    batch_size: int
    data_fraction: float, used to calculate n_shots

  Returns:
    input_fn, input function to be passed to `tf.Estimator`.
  """
  dloader = data_loader.get_dataset_instance(
      {'dataset': dataset, 'data_dir': None})
  num_classes = dloader.get_num_classes()
  n_shots = max(int(1000 * data_fraction / num_classes), 1)
  logging.info('n_shots: %d', n_shots)
  def _dict_to_tuple(batch):
    return batch['image'], batch['label']
  dataset = dloader.get_tf_data(
      split_name='trainval',
      batch_size=batch_size,
      preprocess_fn=functools.partial(
          data_loader.preprocess_fn,
          input_range=(-1.0, 1.0),
          size=image_size),
      epochs=0,
      drop_remainder=False,
      for_eval=False,
      shuffle_buffer_size=1,
      prefetch=1,
      train_examples=None,
  ).unbatch().map(_dict_to_tuple)
  filtered_dataset = _filter_to_k_shot(dataset, num_classes, n_shots)
  return filtered_dataset.shuffle(1000).batch(batch_size)

# %%
def create_vtab_dataset(dataset, image_size, batch_size, mode,
                        eval_mode='test', valid_fold_id=4):
  """Creates a VTAB input_fn to be used by `tf.Estimator`.

  Note: There is one episode/VTAB dataset.

  Args:
    dataset: str, VTAB task to evaluate on.
    image_size: int
    batch_size: int
    mode: str in {'train', 'eval'}, whether to build the input function for
      training or evaluation.
    eval_mode: str in {'valid', 'test'}, whether to build the input functions
      for validation or test runs.
    valid_fold_id: int, 0 <= valid_fold_id < 5, valid_fold_id=4 corresponds to
      the default value in VTAB.

  Returns:
    input_fn, input function to be passed to `tf.Estimator`.
  """
  assert 0 <= valid_fold_id < 5
  dloader = data_loader.get_dataset_instance(
      {'dataset': dataset, 'data_dir': None})
  if mode not in ('train', 'eval'):
    raise ValueError("mode should be 'train' or 'eval'")
  is_training = mode == 'train'

  def _dict_to_tuple(batch):
    return batch['image'], batch['label']
  if eval_mode == 'test':
    split_name = 'train800val200' if is_training else 'test'
  elif eval_mode == 'valid':
    val_start, val_end = valid_fold_id * 200, (valid_fold_id + 1) * 200
    if is_training:
      split_name = f'train[:{val_start}]+train[{val_end}:1000]'
    else:
      split_name = f'train[{val_start}:{val_end}]'
    logging.info('Using split_name: %s', split_name)

    if split_name not in dloader._tfds_splits:
      dloader._tfds_splits[split_name] = split_name
      dloader._num_samples_splits[split_name] = 800 if is_training else 200
  else:
    raise ValueError(f'eval_mode: {eval_mode} invalid')

  return dloader.get_tf_data(
      split_name=split_name,
      batch_size=batch_size,
      preprocess_fn=functools.partial(
          data_loader.preprocess_fn,
          input_range=(-1.0, 1.0),
          size=image_size),
      epochs=0,
      drop_remainder=False,
      for_eval=not is_training,
      # Our training data has at most 1000 samples, therefore a shuffle buffer
      # size of 1000 is sufficient.
      shuffle_buffer_size=1000,
      prefetch=1,
      train_examples=None,
  ).map(_dict_to_tuple)

# %%
class InputPipelineTest(parameterized.TestCase, tf.test.TestCase):

  @parameterized.parameters(
      (84, 2, 'train', 'test'),
      (84, 2, 'eval', 'test'),
      (84, 1000, 'train', 'test'),
      (84, 1000, 'eval', 'test'),
      (240, 2, 'train', 'test'),
      (240, 2, 'train', 'valid'),
      (240, 2, 'eval', 'valid'),
  )
  def test_vtab_pipeline(self, image_size, batch_size, mode, eval_mode):
    data_source = 'data.caltech101'
    dataset = create_vtab_dataset(
        dataset=data_source, mode=mode, image_size=image_size,
        batch_size=batch_size, eval_mode=eval_mode)
    if batch_size <= 1000:
      x, y = next(iter(dataset))
      self.assertAllEqual(x.shape, [batch_size, image_size, image_size, 3])
      self.assertAllEqual(y.shape, [batch_size])
    if batch_size == 1000 and mode == 'train':
      # Full batch.
      self.assertLen(list(iter(dataset)), 1)

# %%
class FinetuneTest(parameterized.TestCase, tf2.test.TestCase):

  # @parameterized.named_parameters(('r50', 'imagenetr50'),
  #                                 ('vitb16', 'imagenetvitB16'))
  def test_evaluate(self, model_name):
    """Tests whether the model runs with no-error using dummy inputs."""
    self.config = get_config(model_name)
    self.sur_model = Finetune(self.config)
    dataset = tf2.data.Dataset.from_tensor_slices(
        (tf2.random.uniform([4, 240, 240, 3]),
         tf2.random.uniform([4,], maxval=2, dtype=tf2.int32))).batch(2)
    results = self.sur_model.evaluate(self.config.learning, dataset, dataset)
    print(results)

# %%
class FinetuneFSTest(parameterized.TestCase, tf2.test.TestCase):

  @parameterized.named_parameters(('r50', 'imagenetr50'),
                                  ('vitb16', 'imagenetvitB16'))
  def test_evaluate(self, model_name):
    """Tests whether the model runs with no-error using dummy inputs."""
    self.config = get_config_fs(model_name)
    self.sur_model = FinetuneFS(self.config)
    dataset = tf2.data.Dataset.from_tensor_slices(
        (tf2.random.uniform([4, 240, 240, 3]),
         tf2.random.uniform([4,], maxval=2, dtype=tf2.int32))).batch(2)
    results = self.sur_model.evaluate(self.config.learning, dataset, dataset)
    print(results)

# %%
ft = FinetuneTest(('r50', 'imagenetr50'), ('vitb16', 'imagenetvitB16'))

# %% [markdown]
# copyright: [2022 Head2Toe Authors](https://github.com/google-research/head2toe)

# %% [markdown]
# # Reference:
#
# 1. [Keras-MMoE](https://github.com/drawbridge/keras-mmoe)
# 2. [Text classification with Switch Transformer](https://keras.io/examples/nlp/text_classification_with_switch_transformer/)
# 3. [mtlearn](https://github.com/AmazaspShumik/mtlearn)
# 4. [The Sparsely Gated Mixture of Experts Layer for PyTorch](https://github.com/davidmrau/mixture-of-experts)
# 5. [LibMTL](https://github.com/median-research-group/LibMTL)
# 6. [Head2Toe: Utilizing Intermediate Representations for Better OOD Generalization](https://github.com/google-research/head2toe)
# 7. [Multi-task learning with Multi-gate Mixture-of-experts](https://towardsdatascience.com/multi-task-learning-with-multi-gate-mixture-of-experts-b46efac3268)
# 8. [Towards Out-Of-Distribution Generalization: A Survey](https://arxiv.org/abs/2108.13624)
# 9. [Head2Toe: Utilizing Intermediate Representations for Better Transfer Learning](https://paperswithcode.com/paper/head2toe-utilizing-intermediate-1/review/)
# 10. [Modeling Task Relationships in Multi-task Learning with Multi-gate Mixture-of-Experts](https://www.youtube.com/watch?v=Dweg47Tswxw&t=12s&ab_channel=KDD2018video)
